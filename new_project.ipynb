# %%
def fix_font():
  import os
  import matplotlib as mpl
  import matplotlib.pyplot as plt
  os.system("apt-get install -y fonts-nanum")
  os.system("fc-cache -fv")
  mpl.font_manager._rebuild()
  findfont=mpl.font_manager.fontManager.findfont
  mpl.font_manager.findfont=findfont
  mpl.backends.backend_agg.findfont=findfont
  plt.rcParams["font.family"]="NanumBarunGothic"
  plt.rcParams["axes.unicode_minus"] = False


fix_font()

# %%
import pandas as pd
df=pd.read_csv("/content/생필품 농수축산물 가격 정보(2021년1월_6월).csv",encoding="cp949")
df
# Out:
#           일련번호  시장/마트 번호  시장/마트 이름  품목 번호       품목 이름      실판매규격  가격(원)  \
# 0      1673336         2    신세계백화점    133      무(세척무)         1개   2980
# 1      1667985       228    방배종합시장     23          상추     1봉150g   1500
# 2      1666935         1      통인시장    266  고등어(생물,국산)        1마리   4000
# 3      1671116        25  방학동도깨비시장    268  고등어(냉동,국산)       350g   2500
# 4      1667066         6   이마트 용산점    171     달걀(10개)        15구   5980
# ...        ...       ...       ...    ...         ...        ...    ...
# 42694  1636118       226  롯데마트 구로점    171     달걀(10개)  10개(600g)   2990
# 42695  1636108       226  롯데마트 구로점     27           배  1개 (600g)   1590
# 42696  1636114       226  롯데마트 구로점    312         애호박  1개 (300g)   2790
# 42697  1636113       226  롯데마트 구로점     22          오이  1개 (200g)   1190
# 42698  1636121       226  롯데마트 구로점    302          명태  1마리(600g)   1670
#
#           년도-월          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드  \
# ...

# %%
df.columns
# Out:
# Index(['일련번호', '시장/마트 번호', '시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)',
#        '년도-월', '비고', '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드',
#        '자치구 이름', '점검일자'],
#       dtype='object')

# %%
jundf=df[df["년도-월"]=="2021-06"]
jundf
# Out:
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호         품목 이름              실판매규격  \
# 0     1673336         2     신세계백화점    133        무(세척무)                 1개
# 1     1667985       228     방배종합시장     23            상추             1봉150g
# 2     1666935         1       통인시장    266    고등어(생물,국산)                1마리
# 3     1671116        25   방학동도깨비시장    268    고등어(냉동,국산)               350g
# 4     1667066         6    이마트 용산점    171       달걀(10개)                15구
# ...       ...       ...        ...    ...           ...                ...
# 6805  1668422        16  현대백화점 미아점    305  사과(부사, 300g)  1개  (3 개 13,000원)
# 6806  1668426        16  현대백화점 미아점    309    양파(1.5kg망)   1망(1,8kg 4,200원)
# 6807  1668978        10       용문시장    305  사과(부사, 300g)              1팩 2개
# 6808  1668427        16  현대백화점 미아점     23            상추               100g
# 6809  1668428        16  현대백화점 미아점    311       오이(다다기)     1개 (5개 3,000원)
#
# ...

# %%
eggjundf=jundf[jundf["품목 이름"].str.contains("달걀")==True]
eggjundf
# Out:
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호    품목 이름       실판매규격  가격(원)  \
# 4     1667066         6    이마트 용산점    171  달걀(10개)         15구   5980
# 11    1671112        25   방학동도깨비시장    320  달걀(30개)       1.8kg   9500
# 26    1668433        16  현대백화점 미아점    171  달걀(10개)         10개   6000
# 28    1668434        16  현대백화점 미아점    320  달걀(30개)         30개      0
# 43    1670908        82   롯데마트 강변점    320  달걀(30개)         30개  10800
# ...       ...       ...        ...    ...      ...         ...    ...
# 6756  1672097       102      목3동시장    320  달걀(30개)         30개   9800
# 6771  1674008       102      목3동시장    320  달걀(30개)         30개   9500
# 6774  1674902        16  현대백화점 미아점    171  달걀(10개)  10개 (600g)   6000
# 6779  1674903        16  현대백화점 미아점    320  달걀(30개)         30개      0
# 6799  1673498        10       용문시장    320  달걀(30개)         30개  10500
#
#          년도-월       비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# ...

# %%
eggjundf30=eggjundf[eggjundf["품목 이름"].str.contains("30")==True]
eggjundf30
# Out:
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호    품목 이름       실판매규격  가격(원)  \
# 11    1671112        25   방학동도깨비시장    320  달걀(30개)       1.8kg   9500
# 28    1668434        16  현대백화점 미아점    320  달걀(30개)         30개      0
# 43    1670908        82   롯데마트 강변점    320  달걀(30개)         30개  10800
# 52    1667084        10       용문시장    320  달걀(30개)         30개  10500
# 62    1671401        42    이마트 가양점    320  달걀(30개)  30개(1800g)   6900
# ...       ...       ...        ...    ...      ...         ...    ...
# 6749  1667596       102      목3동시장    320  달걀(30개)         30구  10100
# 6756  1672097       102      목3동시장    320  달걀(30개)         30개   9800
# 6771  1674008       102      목3동시장    320  달걀(30개)         30개   9500
# 6779  1674903        16  현대백화점 미아점    320  달걀(30개)         30개      0
# 6799  1673498        10       용문시장    320  달걀(30개)         30개  10500
#
#          년도-월        비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# ...

# %%
eggjundf30["가격(원)"].mean()
# Out:
# 9006.852713178294

# %%
eggjundf30["가격(원)"].min()
# Out:
# 0

# %%
eggjundf30["가격(원)"].max()
# Out:
# 75000

# %%
gu=eggjundf30[eggjundf30["자치구 이름"]=="양천구"]
gu
# Out:
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호    품목 이름 실판매규격  가격(원)     년도-월  \
# 184   1674025       103      신영시장    320  달걀(30개)   30개   7000  2021-06
# 212   1669879       103      신영시장    320  달걀(30개)   30구   7000  2021-06
# 254   1672080       103      신영시장    320  달걀(30개)   30개   7000  2021-06
# 288   1667615       103      신영시장    320  달걀(30개)   30구   7980  2021-06
# 463   1669860       102     목3동시장    320  달걀(30개)   30구   9800  2021-06
# 3074  1667634       214   이마트 목동점    320  달걀(30개)   30구   7980  2021-06
# 5714  1667653       223  홈플러스 목동점    320  달걀(30개)   30규   6950  2021-06
# 5723  1672114       223  홈플러스 목동점    320  달걀(30개)   30구   6900  2021-06
# 5733  1669898       223  홈플러스 목동점    320  달걀(30개)   30개   6590  2021-06
# 5753  1674059       223  홈플러스 목동점    320  달걀(30개)   30개   6900  2021-06
# 6125  1672063       214   이마트 목동점    320  달걀(30개)   30구   6900  2021-06
# 6161  1669917       214   이마트 목동점    320  달걀(30개)   30구   6900  2021-06
# ...

# %%
dong=gu[gu["시장/마트 이름"]=="홈플러스 목동점"]
dong
# Out:
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호    품목 이름 실판매규격  가격(원)     년도-월  \
# 5714  1667653       223  홈플러스 목동점    320  달걀(30개)   30규   6950  2021-06
# 5723  1672114       223  홈플러스 목동점    320  달걀(30개)   30구   6900  2021-06
# 5733  1669898       223  홈플러스 목동점    320  달걀(30개)   30개   6590  2021-06
# 5753  1674059       223  홈플러스 목동점    320  달걀(30개)   30개   6900  2021-06
#
#                  비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 5714         국내산,대란                  2              대형마트  470000    양천구
# 5723  국내산 닭이낳은알(대란)                  2              대형마트  470000    양천구
# 5733         국내산,대란                  2              대형마트  470000    양천구
# 5753      국내산 ,신선대란                  2              대형마트  470000    양천구
#
#             점검일자
# 5714  2021-06-24
# 5723  2021-06-24
# 5733  2021-06-24
# 5753  2021-06-24

# %%
x=gu["시장/마트 이름"]
y=gu["가격(원)"]

plt.figure(figsize=(10,10))
plt.bar(x,y)
plt.title("양천구 계란 가격")
plt.xlabel("시장/마트 이름")
plt.ylabel("가격 (원)")
plt.xticks(rotation=0)
plt.show()

# %%
eggjundf30["시장/마트 이름"]=eggjundf30["시장/마트 이름"].astype("category")


x=eggjundf30["시장/마트 이름"]
y=eggjundf30["가격(원)"]

plt.figure(figsize=(30,10))
plt.scatter(x,y)
plt.title("마트 지점별 계란 가격")
plt.xlabel("시장/마트 이름")
plt.ylabel("가격 (원)")
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-104-5ef217c354f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eggjundf30["시장/마트 이름"]=eggjundf30["시장/마트 이름"].astype("category")
